# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidFernandoS95/catbot_web/blob/main/catbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# !pip install huggingface_hub
# !pip install sentence_transformers

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# %%
import requests

url = "https://github.com/DavidFernandoS95/catbot_web/blob/849ecd3494d676b5953b8391b6e820972a1e94a3/test.txt"
res = requests.get(url)
with open("test.txt", "w") as f:
  f.write(res.text)

# %%
from langchain.document_loaders import TextLoader
loader = TextLoader('./test.txt')
documents = loader.load()

# %%
documents
# Out:
# [Document(page_content='{"payload":{"allShortcutsEnabled":false,"fileTree":{"":{"items":[{"name":".gitignore","path":".gitignore","contentType":"file"},{"name":"I parte.pdf","path":"I parte.pdf","contentType":"file"},{"name":"I parte.txt","path":"I parte.txt","contentType":"file"},{"name":"README.md","path":"README.md","contentType":"file"},{"name":"test.txt","path":"test.txt","contentType":"file"}],"totalCount":5}},"fileTreeProcessingTime":1.8951479999999998,"foldersToFetch":[],"reducedMotionEnabled":null,"repo":{"id":739140191,"defaultBranch":"main","name":"catbot_web","ownerLogin":"DavidFernandoS95","currentUserCanPush":false,"isFork":false,"isEmpty":false,"createdAt":"2024-01-04T21:37:37.000Z","ownerAvatar":"https://avatars.githubusercontent.com/u/58567352?v=4","public":true,"private":false,"isOrgOwned":false},"symbolsExpanded":false,"treeExpanded":true,"refInfo":{"name":"849ecd3494d676b5953b8391b6e820972a1e94a3","listCacheKey":"v0:1704476864.0","canEdit":false,"refType":"tree","
# ...
